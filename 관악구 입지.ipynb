# %% [markdown]
# # 1. 관악구 임대사업자 좌표

# %%
import pandas as pd

df = pd.read_csv ('C:/Users/jwkan/OneDrive/바탕 화면/융복합 빅데이터/서울특별시_관악구_임대사업자등록현황_20210614.csv')
df
# Out:
#         영업구분    사업자구분    임대주택구분               도로명주소          종류     유형      면적
# 0      등록영업중    임대사업자  민간매입임대주택    서울특별시 관악구 원신3길 8  장기일반민간임대주택   단독주택   85.62
# 1      등록영업중    임대사업자  민간매입임대주택  서울특별시 관악구 인헌21길 34  장기일반민간임대주택   단독주택  198.01
# 2      등록영업중    임대사업자  민간매입임대주택  서울특별시 관악구 인헌21길 34  장기일반민간임대주택    아파트   84.91
# 3      등록영업중    임대사업자  민간매입임대주택  서울특별시 관악구 인헌21길 34  장기일반민간임대주택  다세대주택   39.14
# 4      등록영업중    임대사업자  민간매입임대주택  서울특별시 관악구 인헌21길 34  장기일반민간임대주택    아파트   27.36
# ...      ...      ...       ...                 ...         ...    ...     ...
# 17104  등록영업중  매입임대사업자  민간매입임대주택                 NaN      매입임대주택  다세대주택   32.87
# 17105  등록영업중  매입임대사업자  민간매입임대주택                 NaN      매입임대주택  다세대주택   29.34
# 17106  등록영업중  매입임대사업자  민간매입임대주택                 NaN      매입임대주택  다세대주택   42.32
# 17107  등록영업중  매입임대사업자  민간매입임대주택                 NaN      매입임대주택  다세대주택   42.32
# 17108  등록영업중  매입임대사업자  민간매입임대주택                 NaN      매입임대주택  다세대주택   32.87
#
# ...

# %%
df_home = df.loc[df.도로명주소.str.contains("관악구", na=False)]

# %%
address = df_home.도로명주소

# %%
address.isnull().sum()
# Out:
# 0

# %%
import pandas as pd
import googlemaps

googlemaps_key = "AIzaSyBIDrZRWKmweeSbM9T0GwQmy3B1bMOgFAI"
gmaps = googlemaps.Client(key=googlemaps_key)

lat, lng = [], []

for i, location in enumerate(address_df['주소']):
    try:
        geo_location = gmaps.geocode(address_df['주소'][i])[0].get('geometry')
        lat.append(geo_location['location']['lat'])
        lng.append(geo_location['location']['lng'])
    except:
        print(f"{i}번째 {(address_df.iloc[i, 3])}의 좌표를 찾을 수 없음")
        lat.append(i)
        lng.append(i)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 import googlemaps
#       4 googlemaps_key = "AIzaSyBIDrZRWKmweeSbM9T0GwQmy3B1bMOgFAI"
#       5 gmaps = googlemaps.Client(key=googlemaps_key)
#
# ModuleNotFoundError: No module named 'googlemaps'

# %%
lat = pd.Series(lat)

# %%
lng = pd.Series(lng)

# %%
r_home = pd.concat([lat, lng], axis=1)

# %%
r_home=pd.concat([address_df,r_home],axis=1)

# %%
r_home= r_home.drop(["위도", "경도"], axis=1)

# %%
r_home

# %%
r_home.rename(columns = {0:'위도',1:'경도'},inplace=True)

# %%
r_home.to_csv("관악구 임대 좌표.csv", mode='w')

# %%
df2 = pd.read_csv ('관악구 임대 좌표.csv')

# %%
df2
# Out:
#       Unnamed: 0     유형                  주소         위도          경도
# 0              0   단독주택    서울특별시 관악구 원신3길 8  37.478406  126.951613
# 1              1   단독주택  서울특별시 관악구 인헌21길 34  37.470297  126.970064
# 2              2    아파트  서울특별시 관악구 인헌21길 34  37.470297  126.970064
# 3              3  다세대주택  서울특별시 관악구 인헌21길 34  37.470297  126.970064
# 4              4    아파트  서울특별시 관악구 인헌21길 34  37.470297  126.970064
# ...          ...    ...                 ...        ...         ...
# 7239        7239  다세대주택  서울특별시 관악구 장군봉7길 20  37.480307  126.940244
# 7240        7240  다세대주택  서울특별시 관악구 장군봉7길 20  37.480307  126.940244
# 7241        7241  다세대주택  서울특별시 관악구 장군봉7길 20  37.480307  126.940244
# 7242        7242  다세대주택  서울특별시 관악구 장군봉7길 20  37.480307  126.940244
# 7243        7243  다세대주택  서울특별시 관악구 장군봉7길 20  37.480307  126.940244
#
# [7244 rows x 5 columns]

# %%
df2 = df2[(df2['유형']=='다가구주택')]

# %% [markdown]
# # 2. 관악구 커피 전문점 위치

# %%
import pandas as pd

df = pd.read_csv ('C:/Users/jwkan/OneDrive/바탕 화면/융복합 빅데이터/fulldata_07_24_05_P_휴게음식점.csv')
df.dropna(subset = ['소재지전체주소'])
# Out:
# C:\Users\jwkan\AppData\Local\Temp\ipykernel_28184\4185244569.py:3: DtypeWarning: Columns (16,39,44,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv ('C:/Users/jwkan/OneDrive/바탕 화면/융복합 빅데이터/fulldata_07_24_05_P_휴게음식점.csv')
#             번호 개방서비스명    개방서비스아이디  개방자치단체코드                    관리번호     인허가일자  \
# 0            1  휴게음식점  07_24_05_P   3150000  3150000-104-2022-00138  20220519
# 1            2  휴게음식점  07_24_05_P   5530000  5530000-104-2022-00268  20220517
# 2            3  휴게음식점  07_24_05_P   4050000  5620000-104-2022-00062  20220428
# 3            4  휴게음식점  07_24_05_P   3220000  3220000-104-2022-00244  20220517
# 4            5  휴게음식점  07_24_05_P   3940000  4100100-104-2022-00062  20220428
# ...        ...    ...         ...       ...                     ...       ...
# 499347  499348  휴게음식점  07_24_05_P   3610000  3610000-104-2018-00018  20180314
# 499348  499349  휴게음식점  07_24_05_P   3610000  3610000-104-2018-00027  20180410
# ...

# %%
df.loc[df['개방자치단체코드'] == 3000000, '개방자치단체코드'] = '종로구'
df.loc[df['개방자치단체코드'] == 3010000, '개방자치단체코드'] = '중구'
df.loc[df['개방자치단체코드'] == 3020000, '개방자치단체코드'] = '용산구'
df.loc[df['개방자치단체코드'] == 3030000, '개방자치단체코드'] = '성동구'
df.loc[df['개방자치단체코드'] == 3040000, '개방자치단체코드'] = '광진구'
df.loc[df['개방자치단체코드'] == 3050000, '개방자치단체코드'] = '동대문구'
df.loc[df['개방자치단체코드'] == 3060000, '개방자치단체코드'] = '중랑구'
df.loc[df['개방자치단체코드'] == 3070000, '개방자치단체코드'] = '성북구'
df.loc[df['개방자치단체코드'] == 3080000, '개방자치단체코드'] = '강북구'
df.loc[df['개방자치단체코드'] == 3090000, '개방자치단체코드'] = '도봉구'
df.loc[df['개방자치단체코드'] == 3100000, '개방자치단체코드'] = '노원구'
df.loc[df['개방자치단체코드'] == 3110000, '개방자치단체코드'] = '은평구'
df.loc[df['개방자치단체코드'] == 3120000, '개방자치단체코드'] = '서대문구'
df.loc[df['개방자치단체코드'] == 3130000, '개방자치단체코드'] = '마포구'
df.loc[df['개방자치단체코드'] == 3140000, '개방자치단체코드'] = '양천구'
df.loc[df['개방자치단체코드'] == 3150000, '개방자치단체코드'] = '강서구'
df.loc[df['개방자치단체코드'] == 3160000, '개방자치단체코드'] = '구로구'
df.loc[df['개방자치단체코드'] == 3170000, '개방자치단체코드'] = '금천구'
df.loc[df['개방자치단체코드'] == 3180000, '개방자치단체코드'] = '영등포구'
df.loc[df['개방자치단체코드'] == 3190000, '개방자치단체코드'] = '동작구'
df.loc[df['개방자치단체코드'] == 3200000, '개방자치단체코드'] = '관악구'
df.loc[df['개방자치단체코드'] == 3210000, '개방자치단체코드'] = '서초구'
df.loc[df['개방자치단체코드'] == 3220000, '개방자치단체코드'] = '강남구'
df.loc[df['개방자치단체코드'] == 3230000, '개방자치단체코드'] = '송파구'
df.loc[df['개방자치단체코드'] == 3240000, '개방자치단체코드'] = '강동구'

# %%
df['사업장명'].value_counts()
# Out:
# 정다방         501
# 별다방         483
# 수다방         479
# 약속다방        432
# 이삭토스트       417
#            ...
# 루브르베이커리       1
# 성신휴게실         1
# 써클K용답대로점      1
# 바보커피숍         1
# 엔젤pc          1
# Name: 사업장명, Length: 339411, dtype: int64

# %%
# 관악구에 있는 커피 전문점
df = df[(df['업태구분명']=='커피숍') | (df['업태구분명']=='다방')| (df['업태구분명']=='까페')]
df = df[(df['사업장명'].str.contains('스타벅스')==False)]
df_coffee = df[(df['영업상태명']=='영업/정상')]
df_coffee = df.loc[df.소재지전체주소.str.contains('관악구',na=False)]
#df_coffee = df.loc[df.소재지전체주소.str.contains("대학동", na=False)|df.소재지전체주소.str.contains("서원동", na=False)|df.소재지전체주소.str.contains("낙성대동", na=False)|df.소재지전체주소.str.contains("신림동", na=False)|df.소재지전체주소.str.contains("청룡동", na=False)]

# %%
address = df_coffee['소재지전체주소']
address
# Out:
# 265           서울특별시 관악구 봉천동 30-3 호삼빌딩
# 621               서울특별시 관악구 봉천동 696-9
# 1408           서울특별시 관악구 봉천동 851-10번지
# 1628      서울특별시 관악구 봉천동 1671-35 신화로즈빌
# 1723            서울특별시 관악구 남현동 1061-22
#                      ...
# 486406         서울특별시 관악구 봉천동 926-36번지
# 487210     서울특별시 관악구 신림동 산 56-1 서울대학교
# 487295      서울특별시 관악구 봉천동 853-2번지 준빌딩
# 487653        서울특별시 관악구 봉천동 100-137번지
# 487867     서울특별시 관악구 봉천동 1562-18 제이빌딩
# Name: 소재지전체주소, Length: 1850, dtype: object

# %%
from pyproj import Proj, transform
import pandas as pd

# Projection 정의
# 중부원점(Bessel): 서울 등 중부지역 EPSG:2097
proj_1 = Proj(init='epsg:2097')

# WGS84 경위도: GPS가 사용하는 좌표계 EPSG:4326
proj_2 = Proj(init='epsg:4326')

DataFrame = df_coffee.copy()

x_list = []
y_list = []

for idx, row in DataFrame.iterrows():
    x, y = row['좌표정보(x)'], row['좌표정보(y)']
    x_, y_ = transform(proj_1, proj_2, x, y)
    x_list.append(x_)
    y_list.append(y_)
    
df_coffee['경도'] = x_list
df_coffee['위도'] = y_list
# Out:
# C:\Users\jwkan\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\jwkan\anaconda3\envs\geo_env\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ...

# %%
df_coffee
# Out:
#             번호 개방서비스명    개방서비스아이디 개방자치단체코드                    관리번호     인허가일자  \
# 265        266  휴게음식점  07_24_05_P      관악구  3200000-104-2021-00014  20210119
# 621        622  휴게음식점  07_24_05_P      관악구  3200000-104-2021-00005  20210106
# 1408      1409  휴게음식점  07_24_05_P      관악구  3200000-104-2018-00181  20181112
# 1628      1629  휴게음식점  07_24_05_P      관악구  3200000-104-2018-00203  20181212
# 1723      1724  휴게음식점  07_24_05_P      관악구  3200000-104-2018-00183  20181114
# ...        ...    ...         ...      ...                     ...       ...
# 486406  486407  휴게음식점  07_24_05_P      관악구  3200000-104-2019-00060  20190315
# 487210  487211  휴게음식점  07_24_05_P      관악구  3200000-104-2019-00034  20190215
# 487295  487296  휴게음식점  07_24_05_P      관악구  3200000-104-2019-00020  20190125
# 487653  487654  휴게음식점  07_24_05_P      관악구  3200000-104-2019-00015  20190118
# 487867  487868  휴게음식점  07_24_05_P      관악구  3200000-104-2019-00016  20190122
#
# ...

# %% [markdown]
# ## 3. 관악구 지하철 승하차 인원 확인

# %%
import pandas as pd

sub = pd.read_csv ('C:/Users/jwkan/OneDrive/바탕 화면/융복합 빅데이터/서울시 지하철 호선별 역별 시간대별 승하차 인원 정보.csv')

# %%
gwan_sub = sub[sub['지하철역'].str.contains('신림')|sub['지하철역'].str.contains('봉천')|sub['지하철역'].str.contains('서울대입구')|sub['지하철역'].str.contains('서원')|sub['지하철역'].str.contains('당곡')|sub['지하철역'].str.contains('서울대벤처타운')|sub['지하철역'].str.contains('관악산역')]

# %%
gwan_sub = gwan_sub[['지하철역','07시-08시 승차인원','07시-08시 하차인원','08시-09시 승차인원','08시-09시 하차인원']]
gwan_sub['아침 승차인원']  = gwan_sub['07시-08시 승차인원']+gwan_sub['08시-09시 승차인원']
gwan_sub['아침 하차인원']  = gwan_sub['07시-08시 하차인원']+gwan_sub['08시-09시 하차인원']

# %%
sub_out = gwan_sub.groupby('지하철역')['아침 승차인원'].sum()
sub_out.sort_values()
# Out:
# 지하철역
# 당곡                 1785
# 서원                 1919
# 서울대벤처타운            3678
# 서울대입구           7299334
# 봉천             17535619
# 서울대입구(관악구청)    21468443
# 신림             49439911
# Name: 아침 승차인원, dtype: int64

# %%
sub_in = gwan_sub.groupby('지하철역')['아침 하차인원'].sum()
sub_in.sort_values()
# Out:
# 지하철역
# 서원                 320
# 당곡                 749
# 서울대벤처타운           1169
# 서울대입구          2546051
# 봉천             3647969
# 서울대입구(관악구청)    6870256
# 신림             9317184
# Name: 아침 하차인원, dtype: int64

# %%
sub_sum = sub_in+sub_out
sub_sum.sort_values()
# Out:
# 지하철역
# 서원                 2239
# 당곡                 2534
# 서울대벤처타운            4847
# 서울대입구           9845385
# 봉천             21183588
# 서울대입구(관악구청)    28338699
# 신림             58757095
# dtype: int64

# %%
df_sub= pd.read_excel('C:/Users/jwkan/OneDrive/바탕 화면/융복합 빅데이터/관악구 지하철 좌표.xlsx')
#df_gar.set_index('공원명', inplace = True)
df_sub
# Out:
#      지하철명         위도          경도
# 0     신림역  37.484013  126.927981
# 1     봉천역  37.482354  126.942115
# 2  서울대입구역  37.481349  126.952009

# %%
import pandas as pd
import folium


# 서울 지도 만들기
seoul_map = folium.Map(location=[37.55,126.98], tiles='Stamen Terrain', 
                        zoom_start=12)

#임대사업자 위치 정보를 CircleMarker로 표시
for name, lat, lng in zip(df_coffee.사업장명, df_coffee.위도, df_coffee.경도):
    folium.CircleMarker([lat, lng],
                        radius=3,         # 원의 반지름
                        color='green',         # 원의 둘레 색상
                        fill=True,
                        fill_color='green',    # 원을 채우는 색
                        fill_opacity=1, # 투명도    
                        popup=name
    ).add_to(seoul_map)
    
for name, lat, lng in zip(df_sub.지하철명, df_sub.위도, df_sub.경도):
    folium.Marker([lat, lng], popup=name,icon=folium.Icon('blue', icon='star')).add_to(seoul_map)
    
    
display(seoul_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd

df1 = pd.read_csv ('C:/Users/jwkan/OneDrive/바탕 화면/융복합 빅데이터/행정동별_커피분야_소비인구(2020.03_2020.05).csv')
df1 = df1[(df1['signgu_nm']=='관악구')]
df1 = df1[(df1['year_se']=='20')|(df1['year_se']=='25')]
po = df1.groupby("adstrd_nm")['cnsmr_popltn_co'].sum()

# %%
po = po.sort_values()

# %%
po.plot.bar()
